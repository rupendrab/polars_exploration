# %%
import polars as pl

# %% [markdown]
# ## Read the dataset, check contents and basic stats

# %%
counts = (
    pl.scan_parquet("../data/yellow_tripdata_2026-01.parquet")
    .select(pl.len().alias("Count"))
    .collect()
)

# Display the number of records
display(counts)

# Display the first 5 records
df = (
    pl.scan_parquet("../data/yellow_tripdata_2026-01.parquet")
    .head(5)
    .collect()
)

display(df)
# Out:
# shape: (1, 1)
# ┌─────────┐
# │ Count   │
# │ ---     │
# │ u32     │
# ╞═════════╡
# │ 3724889 │
# └─────────┘
# shape: (5, 20)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ total_amo ┆ congestio ┆ Airport_f ┆ cbd_conge │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ unt       ┆ n_surchar ┆ ee        ┆ stion_fee │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ ge        ┆ ---       ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ f64       ┆ ---       ┆ f64       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆           ┆ f64       ┆           ┆           │
# │          ┆ μs]       ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 1         ┆ … ┆ 15.86     ┆ 2.5       ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:54:04  ┆ 00:59:37  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         ┆ … ┆ 13.65     ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:34:04  ┆ 00:39:47  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         ┆ … ┆ 18.95     ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:57:06  ┆ 01:05:59  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 4         ┆ … ┆ 55.56     ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:15:22  ┆ 00:58:10  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         ┆ … ┆ 23.1      ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:27:13  ┆ 00:40:43  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Explore the common and different columns between the yellow and grenn cab datasets

# %%
yellow_cols = pl.scan_parquet("../data/yellow_tripdata_2026-01.parquet").collect_schema().names()
green_cols = pl.scan_parquet("../data/green_tripdata_2026-01.parquet").collect_schema().names()

print("Only in Yellow")
print(set(yellow_cols) - set(green_cols))
print()

print("Only in Green")
print(set(green_cols) - set(yellow_cols))
print()

print("Common to both")
print(set(yellow_cols).intersection(set(green_cols)))
# Out:
# Only in Yellow
# {'tpep_pickup_datetime', 'Airport_fee', 'tpep_dropoff_datetime'}
#
# Only in Green
# {'trip_type', 'lpep_pickup_datetime', 'lpep_dropoff_datetime', 'ehail_fee'}
#
# Common to both
# {'DOLocationID', 'extra', 'fare_amount', 'tip_amount', 'VendorID', 'RatecodeID', 'improvement_surcharge', 'PULocationID', 'trip_distance', 'passenger_count', 'payment_type', 'tolls_amount', 'mta_tax', 'store_and_fwd_flag', 'cbd_congestion_fee', 'congestion_surcharge', 'total_amount'}

# %% [markdown]
# ## Explore the location ID reference data

# %%
pl.scan_parquet("../data/yellow_tripdata_2026-01.parquet").head(5).collect()
# Out:
# shape: (5, 20)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ total_amo ┆ congestio ┆ Airport_f ┆ cbd_conge │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ unt       ┆ n_surchar ┆ ee        ┆ stion_fee │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ ge        ┆ ---       ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ f64       ┆ ---       ┆ f64       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆           ┆ f64       ┆           ┆           │
# │          ┆ μs]       ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 1         ┆ … ┆ 15.86     ┆ 2.5       ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:54:04  ┆ 00:59:37  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         ┆ … ┆ 13.65     ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:34:04  ┆ 00:39:47  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         ┆ … ┆ 18.95     ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:57:06  ┆ 01:05:59  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 4         ┆ … ┆ 55.56     ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:15:22  ┆ 00:58:10  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2026-01-0 ┆ 2026-01-0 ┆ 0         ┆ … ┆ 23.1      ┆ 2.5       ┆ 0.0       ┆ 0.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:27:13  ┆ 00:40:43  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Now let's create two functions that can return scanned dataframes
# 1. get_data: Taxi Rides Data
# 2. get_location_lookup_data: Location reference data

# %%
from pathlib import Path

def get_data(
    taxi_type: str,
    year: int,
    month: int
) -> pl.DataFrame:
    file_name = f"../data/{taxi_type}_tripdata_{year:04d}-{month:02d}.parquet"
    pat = Path(file_name)
    if not pat.exists():
        raise ValueError(f"File {file_name} is not found!")
    return pl.scan_parquet(file_name)

def get_location_lookup_data() -> pl.DataFrame:
    return pl.scan_csv("../data/taxi_zone_lookup.csv")

# %% [markdown]
# ## Explore rides by hour

# %%
import time

st = time.time()

df_rides_by_hour = (
    # Get Rides dataset for yellow cab, year 2026, month 1
    get_data("yellow", 2026, 1)

    # Derive the hour column from the tpep_pickup_datetime column
    .with_columns(
        pl.col("tpep_pickup_datetime").dt.hour().alias("hour")
    )

    # Group the dataset by hour
    .group_by("hour")

    # Aggregate functions (In this case pl.len() counts the occurences per group
    .agg(
        pl.len().alias("rides")
    )

    # Now compute the percentage of rides from rides
    .with_columns(
        (pl.col("rides") / pl.col("rides").sum() * 100).round(2).alias("pct_of_rides")
    )

    # Sort the result by hour
    .sort("hour")

    # Collect the results in memory for display and downstream use
    .collect()
)

elapsed = time.time() - st
print(f"Time elapsed = {elapsed:5.3f}")

with pl.Config(tbl_rows=24):
    display(df_rides_by_hour)
# Out:
# Time elapsed = 0.036
# shape: (24, 3)
# ┌──────┬────────┬──────────────┐
# │ hour ┆ rides  ┆ pct_of_rides │
# │ ---  ┆ ---    ┆ ---          │
# │ i8   ┆ u32    ┆ f64          │
# ╞══════╪════════╪══════════════╡
# │ 0    ┆ 111867 ┆ 3.0          │
# │ 1    ┆ 77821  ┆ 2.09         │
# │ 2    ┆ 54105  ┆ 1.45         │
# │ 3    ┆ 38645  ┆ 1.04         │
# │ 4    ┆ 28673  ┆ 0.77         │
# │ 5    ┆ 32912  ┆ 0.88         │
# │ 6    ┆ 63721  ┆ 1.71         │
# │ 7    ┆ 113463 ┆ 3.05         │
# │ 8    ┆ 148281 ┆ 3.98         │
# │ 9    ┆ 156894 ┆ 4.21         │
# │ 10   ┆ 161419 ┆ 4.33         │
# │ 11   ┆ 171729 ┆ 4.61         │
# │ 12   ┆ 187435 ┆ 5.03         │
# │ 13   ┆ 195708 ┆ 5.25         │
# │ 14   ┆ 207507 ┆ 5.57         │
# │ 15   ┆ 221677 ┆ 5.95         │
# │ 16   ┆ 227893 ┆ 6.12         │
# │ 17   ┆ 252173 ┆ 6.77         │
# │ 18   ┆ 265574 ┆ 7.13         │
# │ 19   ┆ 234542 ┆ 6.3          │
# │ 20   ┆ 212883 ┆ 5.72         │
# │ 21   ┆ 212544 ┆ 5.71         │
# │ 22   ┆ 194801 ┆ 5.23         │
# │ 23   ┆ 152622 ┆ 4.1          │
# └──────┴────────┴──────────────┘

# %% [markdown]
# ### Plot

# %%
plt.figure(figsize=(10, 5))
plt.bar(
    df_rides_by_hour["hour"].to_list(),
    df_rides_by_hour["pct_of_rides"].to_list(),
    width=4,
)
plt.xlabel("Hour")
plt.ylabel("% of rides")
plt.title("Distribution of Rides by Hour")
plt.xticks(df_rides_by_hour["hour"].to_list())
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Explore rides by pickup-point, dropoff-point

# %%
df_rides_by_pp = (
    get_data("yellow", 2026, 1)
    .join(
        get_location_lookup_data(),
        left_on="PULocationID",
        right_on="LocationID"
    )
    .join(
        get_location_lookup_data(),
        left_on="DOLocationID",
        right_on="LocationID"
    )
    .rename(
        {
            "Borough": "Pick-Up",
            "Borough_right": "Drop-Off"
        }
    )
    .group_by("Pick-Up", "Drop-Off")
    .agg(
        pl.len().alias("rides")
    )
    .with_columns(
        (pl.col("rides") / pl.col("rides").sum() * 100).round(2).alias("pct_of_rides")
    )
    .sort("pct_of_rides", descending=[True])
    .collect()
)

df_rides_by_pp
# Out:
# shape: (59, 4)
# ┌───────────────┬───────────┬─────────┬──────────────┐
# │ Pick-Up       ┆ Drop-Off  ┆ rides   ┆ pct_of_rides │
# │ ---           ┆ ---       ┆ ---     ┆ ---          │
# │ str           ┆ str       ┆ u32     ┆ f64          │
# ╞═══════════════╪═══════════╪═════════╪══════════════╡
# │ Manhattan     ┆ Manhattan ┆ 2959577 ┆ 79.45        │
# │ Queens        ┆ Manhattan ┆ 162216  ┆ 4.35         │
# │ Queens        ┆ Queens    ┆ 107724  ┆ 2.89         │
# │ Manhattan     ┆ Brooklyn  ┆ 93541   ┆ 2.51         │
# │ Manhattan     ┆ Queens    ┆ 84167   ┆ 2.26         │
# │ …             ┆ …         ┆ …       ┆ …            │
# │ Bronx         ┆ EWR       ┆ 1       ┆ 0.0          │
# │ Staten Island ┆ EWR       ┆ 5       ┆ 0.0          │
# │ EWR           ┆ N/A       ┆ 8       ┆ 0.0          │
# │ EWR           ┆ Manhattan ┆ 10      ┆ 0.0          │
# │ N/A           ┆ EWR       ┆ 117     ┆ 0.0          │
# └───────────────┴───────────┴─────────┴──────────────┘

# %% [markdown]
# ## Explore tipping behavior
#
# 1. Choose a dataset
# 2. Filter for data where there was a fare amount (this is just a base check)
# 3. Calculate a Tip Pct column and put it in buckets of 5,10,15,20,....
# 4. Then Group the the Bucket and show the Pct of trips for that bucket

# %%
result = (
    get_data("yellow", 2026, 1)
    .filter(pl.col("fare_amount") > 0)
    .with_columns(
        (((pl.col("tip_amount") / pl.col("fare_amount")) * 100) / 5)
        .round()
        .mul(5)
        .alias("tip_pct_bucket")
    )
    .group_by("tip_pct_bucket")
    .agg(pl.len().alias("rides"))
    .with_columns(
        (pl.col("rides") / pl.col("rides").sum() * 100).round(2).alias("pct_of_rides")
    )
    .sort("tip_pct_bucket")
    .collect()
)

with pl.Config(tbl_rows=min(50, result.height)):
    display(result)
# Out:
# shape: (241, 3)
# ┌────────────────┬─────────┬──────────────┐
# │ tip_pct_bucket ┆ rides   ┆ pct_of_rides │
# │ ---            ┆ ---     ┆ ---          │
# │ f64            ┆ u32     ┆ f64          │
# ╞════════════════╪═════════╪══════════════╡
# │ 0.0            ┆ 1564387 ┆ 42.47        │
# │ 5.0            ┆ 52603   ┆ 1.43         │
# │ 10.0           ┆ 119474  ┆ 3.24         │
# │ 15.0           ┆ 171678  ┆ 4.66         │
# │ 20.0           ┆ 196844  ┆ 5.34         │
# │ 25.0           ┆ 554105  ┆ 15.04        │
# │ 30.0           ┆ 510536  ┆ 13.86        │
# │ 35.0           ┆ 257824  ┆ 7.0          │
# │ 40.0           ┆ 139513  ┆ 3.79         │
# │ 45.0           ┆ 54034   ┆ 1.47         │
# │ 50.0           ┆ 25942   ┆ 0.7          │
# │ 55.0           ┆ 13471   ┆ 0.37         │
# │ 60.0           ┆ 7209    ┆ 0.2          │
# │ 65.0           ┆ 2947    ┆ 0.08         │
# │ 70.0           ┆ 3258    ┆ 0.09         │
# │ 75.0           ┆ 1450    ┆ 0.04         │
# │ 80.0           ┆ 1279    ┆ 0.03         │
# │ 85.0           ┆ 813     ┆ 0.02         │
# │ 90.0           ┆ 655     ┆ 0.02         │
# │ 95.0           ┆ 355     ┆ 0.01         │
# │ 100.0          ┆ 710     ┆ 0.02         │
# │ 105.0          ┆ 187     ┆ 0.01         │
# │ 110.0          ┆ 411     ┆ 0.01         │
# │ 115.0          ┆ 397     ┆ 0.01         │
# │ 120.0          ┆ 158     ┆ 0.0          │
# │ …              ┆ …       ┆ …            │
# │ 2850.0         ┆ 1       ┆ 0.0          │
# │ 3000.0         ┆ 3       ┆ 0.0          │
# │ 3065.0         ┆ 1       ┆ 0.0          │
# │ 3095.0         ┆ 1       ┆ 0.0          │
# │ 3100.0         ┆ 2       ┆ 0.0          │
# │ 3165.0         ┆ 1       ┆ 0.0          │
# │ 3235.0         ┆ 2       ┆ 0.0          │
# │ 3300.0         ┆ 1       ┆ 0.0          │
# │ 3330.0         ┆ 1       ┆ 0.0          │
# │ 3335.0         ┆ 1       ┆ 0.0          │
# │ 3910.0         ┆ 1       ┆ 0.0          │
# │ 4000.0         ┆ 1       ┆ 0.0          │
# │ 5500.0         ┆ 1       ┆ 0.0          │
# │ 5640.0         ┆ 1       ┆ 0.0          │
# │ 7265.0         ┆ 1       ┆ 0.0          │
# │ 7365.0         ┆ 1       ┆ 0.0          │
# │ 7500.0         ┆ 1       ┆ 0.0          │
# │ 8000.0         ┆ 3       ┆ 0.0          │
# │ 10000.0        ┆ 14      ┆ 0.0          │
# │ 10870.0        ┆ 1       ┆ 0.0          │
# │ 11665.0        ┆ 1       ┆ 0.0          │
# │ 16300.0        ┆ 2       ┆ 0.0          │
# │ 16335.0        ┆ 1       ┆ 0.0          │
# │ 150000.0       ┆ 1       ┆ 0.0          │
# │ 300000.0       ┆ 1       ┆ 0.0          │
# └────────────────┴─────────┴──────────────┘

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt

result_plot = result.filter(pl.col("pct_of_rides") > 1)
display(result_plot)
plt.figure(figsize=(10, 5))
plt.bar(
    result_plot["tip_pct_bucket"].to_list(),
    result_plot["pct_of_rides"].to_list(),
    width=4,
)
plt.xlabel("Tip % bucket")
plt.ylabel("% of rides")
plt.title("Distribution of Tip Percentages")
plt.xticks(result_plot["tip_pct_bucket"].to_list())
plt.tight_layout()
plt.show()
# Out:
# shape: (9, 3)
# ┌────────────────┬───────┬──────────────┐
# │ tip_pct_bucket ┆ rides ┆ pct_of_rides │
# │ ---            ┆ ---   ┆ ---          │
# │ f64            ┆ u32   ┆ f64          │
# ╞════════════════╪═══════╪══════════════╡
# │ 0.0            ┆ 14997 ┆ 37.85        │
# │ 5.0            ┆ 722   ┆ 1.82         │
# │ 10.0           ┆ 1685  ┆ 4.25         │
# │ 15.0           ┆ 1853  ┆ 4.68         │
# │ 20.0           ┆ 4638  ┆ 11.71        │
# │ 25.0           ┆ 8325  ┆ 21.01        │
# │ 30.0           ┆ 4205  ┆ 10.61        │
# │ 35.0           ┆ 1751  ┆ 4.42         │
# │ 40.0           ┆ 687   ┆ 1.73         │
# └────────────────┴───────┴──────────────┘
